# %%
import csv
import pandas as pd

# %%
census = pd.read_csv('data.csv')
census.head()
# Out:
#    id       state abbr  poverty  povertyMoe   age  ageMoe  income  incomeMoe  \
# 0   1     Alabama   AL     19.3         0.5  38.6     0.2   42830        598
# 1   2      Alaska   AK     11.2         0.9  33.3     0.3   71583       1784
# 2   4     Arizona   AZ     18.2         0.4  36.9     0.1   50068        483
# 3   5    Arkansas   AR     18.9         0.5  37.8     0.2   41262        653
# 4   6  California   CA     16.4         0.2  36.0     0.1   61933        238
#
#    healthcare  healthcareLow  healthcareHigh  obesity  obesityLow  \
# 0        13.9           12.7            15.1     33.5        32.1
# 1        15.0           13.3            16.6     29.7        27.8
# 2        14.4           13.3            15.6     28.9        27.7
# 3        16.3           14.4            18.2     35.9        33.8
# 4        14.8           13.8            15.8     24.7        23.5
#
#    obesityHigh  smokes  smokesLow  smokesHigh  -0.385218228
# ...

# %%
censusdf = census[['abbr', 'poverty', 'age', 'income', 'healthcare', 'obesity', 'smokes']]
censusdf.head()
# Out:
#   abbr  poverty   age  income  healthcare  obesity  smokes
# 0   AL     19.3  38.6   42830        13.9     33.5    21.1
# 1   AK     11.2  33.3   71583        15.0     29.7    19.9
# 2   AZ     18.2  36.9   50068        14.4     28.9    16.5
# 3   AR     18.9  37.8   41262        16.3     35.9    24.7
# 4   CA     16.4  36.0   61933        14.8     24.7    12.9

# %%
censusdf.dtypes
# Out:
# abbr           object
# poverty       float64
# age           float64
# income          int64
# healthcare    float64
# obesity       float64
# smokes        float64
# dtype: object

# %%
print(len(censusdf))
# Out:
# 51

# %%
censusdf.dropna()
# Out:
#    abbr  poverty   age  income  healthcare  obesity  smokes
# 0    AL     19.3  38.6   42830        13.9     33.5    21.1
# 1    AK     11.2  33.3   71583        15.0     29.7    19.9
# 2    AZ     18.2  36.9   50068        14.4     28.9    16.5
# 3    AR     18.9  37.8   41262        16.3     35.9    24.7
# 4    CA     16.4  36.0   61933        14.8     24.7    12.9
# 5    CO     12.0  36.3   61303        12.8     21.3    15.7
# 6    CT     10.8  40.5   70048         8.7     26.3    15.4
# 7    DE     12.5  39.6   59716         8.7     30.7    19.9
# 8    DC     17.7  33.8   71648         8.3     21.7    16.4
# 9    FL     16.5  41.6   47463        17.6     26.2    17.7
# 10   GA     18.3  36.1   49321        20.9     30.5    17.4
# 11   HI     11.4  38.1   69592         8.1     22.1    14.1
# 12   ID     14.8  35.9   47861        16.5     28.9    15.9
# 13   IL     14.4  37.5   57444        11.9     29.3    16.5
# 14   IN     15.2  37.4   49446        14.8     32.7    22.9
# ...

# %%
print(len(censusdf))
# Out:
# 51

# %%
censusdf.to_csv('newData.csv')
